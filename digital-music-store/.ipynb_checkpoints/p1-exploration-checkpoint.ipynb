# %% [markdown]
# # P1. Exploration

# %% [markdown]
# ## 1. Description Générale
#
# En utilisant DBeaver et les paramètres de connexion donnés par ailleurs, faire une description détaillée de la base de données fournie. Présenter notamment le diagramme entité - relation (ERD) et les différentes caractéristiques des tables de la base.  Quelles types de renseignement peut-on tirer de cette base de données ?

# %% [markdown]
# ER Diagramme de la BDD Fournie :

# %% [markdown]
# ![ER](Pics/ER-Diagramme.png)

# %% [markdown]
# RELATIONS DE LA TABLE PRINCIPALE : TRACK

# %% [markdown]
# ![ER](Pics/ER-Diagramme-Track.png)

# %% [markdown]
# RELATIONS DE LA TABLE PRINCIPALE : CUSTOMER

# %% [markdown]
# ![ER](Pics/ER-Diagramme-Customer.png)

# %% [markdown]
# ---
#
# ## 2. Exploration SQL via python / pandas
# Dans cette partie, on s'attache à explorer la base de données en utilisant le language SQL pour les requêtes et le language Python (+ module pandas) pour récupérer les résultats de façon programmatique.
# Vous pouvez utiliser DBeaver ou outil similaire pour préparer / tester vos requêtes mais celles-ci doivent être reportées et appliquées dans du code Python comme présenté dans les quelques examples à suivre.
# *Pour les résultats "longs", un aperçu des quelques premières lignes et le comptage total des résultats est suffisant.*

# %%
import os
import sqlite3
import pandas as pd

# %%
from pathlib import Path

# %%
# Ouvre connection vers SQLite db
chemin_bdd = Path('db') / 'chinook.db'
conn = sqlite3.connect(chemin_bdd)

# %% [markdown]
# ### Organigramme Compagnie
#
# Q01. Ecrivez et exécutez une unique requête listant chaque employée de la compagnie (Id, nom + prénom, Titre) ainsi que son manager direct (nom + prénom, Titre)

# %%
# requête de départ
query = """
    SELECT e.EmployeeId AS 'Id Employé', 
           e.firstname || ' ' || e.lastname AS 'Nom Employé',
           e.title AS 'Poste',
           e.ReportsTo AS 'Id Manager',
           M.firstname || ' ' || M.lastname AS 'Nom Manager',
           M.title AS 'Poste du Manager'
    FROM employees e
    LEFT JOIN employees M
        ON M.EmployeeId = e.ReportsTo
    ;
"""

# %%
results = pd.read_sql_query(query, conn)
results
# Out:
#    Id Employé       Nom Employé                Poste  Id Manager  \
# 0           1      Andrew Adams      General Manager         NaN
# 1           2     Nancy Edwards        Sales Manager         1.0
# 2           3      Jane Peacock  Sales Support Agent         2.0
# 3           4     Margaret Park  Sales Support Agent         2.0
# 4           5     Steve Johnson  Sales Support Agent         2.0
# 5           6  Michael Mitchell           IT Manager         1.0
# 6           7       Robert King             IT Staff         6.0
# 7           8    Laura Callahan             IT Staff         6.0
#
#         Nom Manager Poste du Manager
# 0              None             None
# 1      Andrew Adams  General Manager
# 2     Nancy Edwards    Sales Manager
# 3     Nancy Edwards    Sales Manager
# 4     Nancy Edwards    Sales Manager
# 5      Andrew Adams  General Manager
# 6  Michael Mitchell       IT Manager
# 7  Michael Mitchell       IT Manager

# %% [markdown]
# Q02. Pour chaque artiste présent dans cette BDD, indiquez le nombre d'albums de cet artiste également répertorié (Liste triée par nom d'artiste)

# %%
query_02 = """
    SELECT `Name` AS 'Nom Artiste', 
            COUNT(DISTINCT AlbumId) AS 'Nombre Albums'
    FROM Albums A 
    INNER JOIN Artists AR 
        ON A.ArtistId = AR.ArtistId
    GROUP BY `Name`
    ORDER BY `Name`
    LIMIT 10;
"""

# %%
results = pd.read_sql_query(query_02, conn)
results
# Out:
#                                          Nom Artiste  Nombre Albums
# 0                                              AC/DC              2
# 1          Aaron Copland & London Symphony Orchestra              1
# 2                                     Aaron Goldberg              1
# 3  Academy of St. Martin in the Fields & Sir Nevi...              1
# 4  Academy of St. Martin in the Fields Chamber En...              1
# 5  Academy of St. Martin in the Fields, John Birc...              1
# 6  Academy of St. Martin in the Fields, Sir Nevil...              1
# 7                                             Accept              2
# 8                     Adrian Leaper & Doreen de Feis              1
# 9                                          Aerosmith              1

# %% [markdown]
# Q03. Produire une liste des albums reprenant également l'artiste de l'album, le nombre de pistes, la durée de toutes les pistes (en minutes) et le coût total (Liste triée par artiste puis nom d'album)

# %%
query_03 = """
    SELECT a.Title AS 'Nom Album',
        AR.Name AS 'Nom Artiste',
        COUNT(DISTINCT pt.TrackId) AS Nb_Pistes,
        t.Milliseconds / 60000 AS Temps_Mn,
        COUNT(DISTINCT pt.TrackId) * t.UnitPrice AS Coût_Total
    FROM albums a 
    INNER JOIN artists AR 
        ON a.ArtistId = AR.ArtistId 
    INNER JOIN tracks t 
        ON a.AlbumId = t.AlbumId 
    INNER JOIN playlist_track pt 
        ON t.TrackId = pt.TrackId 
    GROUP BY a.AlbumId 
    ORDER BY AR.Name, a.Title
    LIMIT 10;
"""

# %%
results = pd.read_sql_query(query_03, conn)
results
# Out:
#                                 Nom Album  \
# 0   For Those About To Rock We Salute You
# 1                       Let There Be Rock
# 2           A Copland Celebration, Vol. I
# 3                                  Worlds
# 4       The World of Classical Favourites
# 5     Sir Neville Marriner: A Celebration
# 6  Fauré: Requiem, Ravel: Pavane & Others
# 7      Bach: Orchestral Suites Nos. 1 - 4
# 8                       Balls to the Wall
# 9                       Restless and Wild
#
#                                          Nom Artiste  Nb_Pistes  Temps_Mn  \
# 0                                              AC/DC         10         5
# 1                                              AC/DC          8         5
# 2          Aaron Copland & London Symphony Orchestra          1         3
# 3                                     Aaron Goldberg          1         4
# 4  Academy of St. Martin in the Fields & Sir Nevi...          2         3
# 5  Academy of St. Martin in the Fields Chamber En...          1         5
# 6  Academy of St. Martin in the Fields, John Birc...          1         4
# 7  Academy of St. Martin in the Fields, Sir Nevil...          1         3
# 8                                             Accept          1         5
# 9                                             Accept          3         3
#
#    Coût_Total
# 0        9.90
# 1        7.92
# 2        0.99
# 3        0.99
# 4        1.98
# 5        0.99
# 6        0.99
# 7        0.99
# 8        0.99
# 9        2.97

# %% [markdown]
# Q04. Produire une liste des toutes les playlists reprenant son nom, le nombre de pistes, la durée de toutes les pistes (en minutes) et le coût total (Liste triée par nom de playlist)

# %%
query_04 = """
    SELECT pl.Name AS 'Nom Playlist',
        COUNT(DISTINCT pt.TrackId) AS Nb_Pistes,
        SUM(DISTINCT t.Milliseconds) / 60000 AS Temps_Mn,
        COUNT(DISTINCT t.TrackId) * t.UnitPrice AS Coût_Total
    FROM tracks t
    INNER JOIN playlist_track pt 
        ON t.TrackId = pt.TrackId 
    INNER JOIN playlist_track ptk
        ON t.TrackId = ptk.TrackId 
    INNER JOIN playlists pl
        ON ptk.PlaylistId = pl.PlaylistId 
    GROUP BY pl.Name 
    ORDER BY pl.Name;
"""

# %%
results = pd.read_sql_query(query_04, conn)
results
# Out:
#                   Nom Playlist  Nb_Pistes  Temps_Mn  Coût_Total
# 0                   90’s Music       1477      6278     1462.23
# 1              Brazilian Music         39       158       38.61
# 2                    Classical         75       362       74.25
# 3    Classical 101 - Deep Cuts         25       112       24.75
# 4   Classical 101 - Next Steps         25       126       24.75
# 5   Classical 101 - The Basics         25       123       24.75
# 6                       Grunge         15        68       14.85
# 7          Heavy Metal Classic         26       136       25.74
# 8                        Music       3290     12920     3257.10
# 9                 Music Videos          1         4        0.99
# 10                 On-The-Go 1          1         3        0.99
# 11                    TV Shows        213      8177      423.87

# %% [markdown]
# Q05. Produire une liste des tous les genres de musique reprenant son genre, le nombre de pistes, la durée de toutes les pistes (en minutes), le coût total et le coût moyen (Liste triée par nom de genre)

# %%
query_05 = """
    SELECT g.Name AS 'Genre',
	COUNT(DISTINCT plt.TrackId) AS Nb_Pistes,
	SUM(DISTINCT t.Milliseconds) / 60000 AS Temps_Mn,
	COUNT(DISTINCT plt.TrackId) * t.UnitPrice AS 'Coût Total',
	AVG(t.UnitPrice) AS 'Coût Moyen'
    FROM genres g
    INNER JOIN tracks t
        ON g.GenreId =t.GenreId 
    INNER JOIN playlist_track plt
        ON plt.TrackId = t.TrackId 
    GROUP BY g.Name 
    ORDER BY g.Name;
"""

# %%
results = pd.read_sql_query(query_05, conn)
results
# Out:
#                  Genre  Nb_Pistes  Temps_Mn  Coût Total  Coût Moyen
# 0          Alternative         40       176       39.60        0.99
# 1   Alternative & Punk        332      1250      328.68        0.99
# 2                Blues         81       364       80.19        0.99
# 3           Bossa Nova         15        54       14.85        0.99
# 4            Classical         74       362       73.26        0.99
# 5               Comedy         17       449       33.83        1.99
# 6                Drama         64      2703      127.36        1.99
# 7       Easy Listening         24        75       23.76        0.99
# 8    Electronica/Dance         30       151       29.70        0.99
# 9          Heavy Metal         28       138       27.72        0.99
# 10         Hip Hop/Rap         35       103       34.65        0.99
# 11                Jazz        130       632      128.70        0.99
# 12               Latin        579      2193      573.21        0.99
# 13               Metal        374      1888      370.26        0.99
# 14               Opera          1         2        0.99        0.99
# 15                 Pop         48       183       47.52        0.99
# 16            R&B/Soul         61       217       60.39        0.99
# 17              Reggae         58       238       57.42        0.99
# 18                Rock       1297      5832     1284.03        0.99
# 19       Rock And Roll         12        26       11.88        0.99
# 20    Sci Fi & Fantasy         26      1261       51.74        1.99
# 21     Science Fiction         13       568       25.87        1.99
# 22          Soundtrack         43       175       42.57        0.99
# 23            TV Shows         93      3324      185.07        1.99
# 24               World         28       104       27.72        0.99

# %% [markdown]
# Q06. Indiquez les caractéristiques principales de toutes les pistes correspondant au genre 'Science Fiction' (nom de piste, album, artiste de l'album, compositeur, nom du type de media, durée (en secondes) et prix unitaire

# %%
query_06= """
    SELECT DISTINCT G.Name AS 'Genre', 
        A.Title AS 'Titre Album', 
        T.Name AS 'Titre Piste', 
        AR.Name AS 'Nom Artiste', 
        T.Composer AS 'Nom Compositeur', 
        MT.Name AS 'Type Media', 
        T.Milliseconds AS 'Temps Ms', 
        T.UnitPrice AS 'Coût Unitaire'
    FROM artists AR 
    INNER JOIN albums A
        ON AR.ArtistId = A.ArtistId 
    INNER JOIN tracks T
        ON A.AlbumId = T.AlbumId 
    INNER JOIN genres G
        ON T.GenreId = G.GenreId 
    INNER JOIN media_types MT 
        ON T.MediaTypeId = MT.MediaTypeId 
    INNER JOIN playlist_track PT
        ON T.TrackId = PT.TrackId 
    INNER JOIN playlists PL
        ON PT.PlaylistId = PL.PlaylistId 
    WHERE G.Name = 'Science Fiction';
"""

# %%
results = pd.read_sql_query(query_06, conn)
results
# Out:
#               Genre                             Titre Album  \
# 0   Science Fiction  Battlestar Galactica: The Story So Far
# 1   Science Fiction          Battlestar Galactica, Season 3
# 2   Science Fiction          Battlestar Galactica, Season 3
# 3   Science Fiction          Battlestar Galactica, Season 3
# 4   Science Fiction          Battlestar Galactica, Season 3
# 5   Science Fiction          Battlestar Galactica, Season 3
# 6   Science Fiction          Battlestar Galactica, Season 3
# 7   Science Fiction          Battlestar Galactica, Season 3
# 8   Science Fiction          Battlestar Galactica, Season 3
# 9   Science Fiction          Battlestar Galactica, Season 3
# 10  Science Fiction          Battlestar Galactica, Season 3
# 11  Science Fiction          Battlestar Galactica, Season 3
# 12  Science Fiction          Battlestar Galactica, Season 3
#
#                                Titre Piste           Nom Artiste  \
# 0   Battlestar Galactica: The Story So Far  Battlestar Galactica
# 1                   A Measure of Salvation  Battlestar Galactica
# 2                                     Hero  Battlestar Galactica
# 3                      Unfinished Business  Battlestar Galactica
# 4                              The Passage  Battlestar Galactica
# 5                       The Eye of Jupiter  Battlestar Galactica
# 6                                  Rapture  Battlestar Galactica
# 7     Taking a Break from All Your Worries  Battlestar Galactica
# 8                           The Woman King  Battlestar Galactica
# 9                        A Day In the Life  Battlestar Galactica
# 10                             Dirty Hands  Battlestar Galactica
# 11                               Maelstrom  Battlestar Galactica
# 12                      The Son Also Rises  Battlestar Galactica
#
#    Nom Compositeur                   Type Media  Temps Ms  Coût Unitaire
# 0             None  Protected MPEG-4 video file   2622250           1.99
# 1             None  Protected MPEG-4 video file   2563938           1.99
# 2             None  Protected MPEG-4 video file   2713755           1.99
# 3             None  Protected MPEG-4 video file   2622038           1.99
# 4             None  Protected MPEG-4 video file   2623875           1.99
# 5             None  Protected MPEG-4 video file   2618750           1.99
# 6             None  Protected MPEG-4 video file   2624541           1.99
# 7             None  Protected MPEG-4 video file   2624207           1.99
# 8             None  Protected MPEG-4 video file   2626376           1.99
# 9             None  Protected MPEG-4 video file   2620245           1.99
# 10            None  Protected MPEG-4 video file   2627961           1.99
# 11            None  Protected MPEG-4 video file   2622372           1.99
# 12            None  Protected MPEG-4 video file   2621830           1.99

# %% [markdown]
# Q07. Retrouvez tous les clients (nom, prénom, email, pays) ayant acheté de la musique de type 'World'

# %%
query_07= """
    SELECT C.FirstName || ' ' || C.LastName AS 'Client', 
	       C.Email AS 'Email', 
           C.Country AS 'Pays', 
           G.Name AS 'Genre'
    FROM customers C
    INNER JOIN invoices I
        ON C.CustomerId = I.CustomerId 
    INNER JOIN invoice_items II
        ON I.InvoiceId = II.InvoiceId 
    INNER JOIN tracks T
        ON II.TrackId = T.TrackId 
    INNER JOIN genres G
        ON T.GenreId = G.GenreId 
    WHERE G.Name = 'World'
    ORDER BY C.Country, C.FirstName;
"""

# %%
results = pd.read_sql_query(query_07, conn)
results
# Out:
#                Client                          Email            Pays  Genre
# 0     Roberto Almeida  roberto.almeida@riotur.gov.br          Brazil  World
# 1     Roberto Almeida  roberto.almeida@riotur.gov.br          Brazil  World
# 2      Aaron Mitchell         aaronmitchell@yahoo.ca          Canada  World
# 3   Jennifer Peterson            jenniferp@rogers.ca          Canada  World
# 4   Jennifer Peterson            jenniferp@rogers.ca          Canada  World
# 5        Mark Philips             mphilips12@shaw.ca          Canada  World
# 6         Martha Silk           marthasilk@gmail.com          Canada  World
# 7         Martha Silk           marthasilk@gmail.com          Canada  World
# 8        Bjørn Hansen          bjorn.hansen@yahoo.no          Norway  World
# 9      João Fernandes            jfernandes@yahoo.pt        Portugal  World
# 10     João Fernandes            jfernandes@yahoo.pt        Portugal  World
# 11   Joakim Johansson      joakim.johansson@yahoo.se          Sweden  World
# 12       Steve Murray          steve.murray@yahoo.uk  United Kingdom  World

# %% [markdown]
# Q08. Nommez les 15 artistes comptant le plus de pistes de type 'Rock'

# %%
query_08 = """
    SELECT AR.Name AS 'Nom Artiste', 
	   COUNT(DISTINCT T.TrackId) AS Nombre_de_Titres,
	   G.Name AS 'Genre'
    FROM artists AR
    INNER JOIN albums A
        ON AR.ArtistId = A.ArtistId 
    INNER JOIN tracks T
        ON A.AlbumId = T.AlbumId 
    INNER JOIN genres G
        ON T.GenreId = G.GenreId 
    WHERE G.Name = 'Rock'
    GROUP BY AR.Name 
    ORDER BY Nombre_de_Titres DESC
    LIMIT 15;
"""

# %%
results = pd.read_sql_query(query_08, conn)
results
# Out:
#                      Nom Artiste  Nombre_de_Titres Genre
# 0                   Led Zeppelin               114  Rock
# 1                             U2               112  Rock
# 2                    Deep Purple                92  Rock
# 3                    Iron Maiden                81  Rock
# 4                      Pearl Jam                54  Rock
# 5                      Van Halen                52  Rock
# 6                          Queen                45  Rock
# 7             The Rolling Stones                41  Rock
# 8   Creedence Clearwater Revival                40  Rock
# 9                           Kiss                35  Rock
# 10                  Foo Fighters                33  Rock
# 11         Red Hot Chili Peppers                31  Rock
# 12                      The Cult                30  Rock
# 13                 Lenny Kravitz                30  Rock
# 14                       Nirvana                29  Rock

# %% [markdown]
# Q09. Nommez les 5 meilleurs clients

# %%
query_09 = """
    SELECT C.FirstName || ' ' || C.LastName AS Client,
	   SUM(I.Total) AS Total_Facturé,
	   COUNT(DISTINCT I.InvoiceId) AS Nb_Factures
    FROM customers C
    INNER JOIN invoices I
        ON C.CustomerId = I.CustomerId  
    GROUP BY Client 
    ORDER BY Total_Facturé DESC
    LIMIT 5;
"""

# %%
results = pd.read_sql_query(query_09, conn)
results
# Out:
#                Client  Total_Facturé  Nb_Factures
# 0         Helena Holý          49.62            7
# 1  Richard Cunningham          47.62            7
# 2          Luis Rojas          46.62            7
# 3     Ladislav Kovács          45.62            7
# 4       Hugh O'Reilly          45.62            7

# %% [markdown]
# Q10. Détaillez (piste, album, artiste, genre et type media) tous les achats effectués par le client 'Richard Cunningham' (triée par date achat)

# %%
query_10 = """
    SELECT A.Title AS Nom_Album,
           T.Name AS Nom_Piste,
           AR.Name AS Nom_Artiste,
           G.Name AS Genre,
           MT.Name AS Media,
           I.InvoiceDate AS Date_Achat
    FROM customers C
    INNER JOIN invoices I
        ON C.CustomerId = I.CustomerId  
    INNER JOIN invoice_items II
        ON I.InvoiceId = II.InvoiceId 
    INNER JOIN tracks T
        ON II.TrackId = T.TrackId 
    INNER JOIN albums A
        ON T.AlbumId = A.AlbumId 
    INNER JOIN artists AR
        ON A.ArtistId = AR.ArtistId 
    INNER JOIN genres G
        ON T.GenreId = G.GenreId 
    INNER JOIN media_types MT
        ON T.MediaTypeId = MT.MediaTypeId 
    WHERE C.FirstName || ' ' || C.LastName = 'Richard Cunningham'
    ORDER BY Date_Achat DESC;
"""

# %%
results = pd.read_sql_query(query_10, conn)
results
# Out:
#                             Nom_Album                        Nom_Piste  \
# 0                      American Idiot                   American Idiot
# 1                      American Idiot                Give Me Novacaine
# 2                      American Idiot                      Whatsername
# 3            Appetite for Destruction                    Paradise City
# 4            Appetite for Destruction                     Rocket Queen
# 5                 Use Your Illusion I              You Ain't the First
# 6                 Use Your Illusion I                   Garden of Eden
# 7                Use Your Illusion II                         14 Years
# 8                Use Your Illusion II                   Pretty Tied Up
# 9      Battlestar Galactica, Season 3                Crossroads, Pt. 1
# 10                   Heroes, Season 1        Seven Minutes to Midnight
# 11                   Heroes, Season 1                      Company Man
# 12                     Lost, Season 2                      Orientation
# 13                     Lost, Season 1          House of the Rising Sun
# 14                     Lost, Season 3              Lost Survival Guide
# 15                     Lost, Season 3                         Enter 77
# 16                     Lost, Season 3                           Exposé
# 17                     Lost, Season 3                         Catch-22
# 18                     Lost, Season 2                              "?"
# 19                       Achtung Baby  Even Better Than The Real Thing
# 20                       Achtung Baby                          Acrobat
# 21    All That You Can't Leave Behind                   Peace On Earth
# 22                  B-Sides 1980-1990                 Dancing Barefoot
# 23                            A-Sides                        Loud Love
# 24                            A-Sides                 Get On The Snake
# 25                       Acústico MTV                 Nebulosa Do Amor
# 26              Sozinho Remix Ao Vivo       Sozinho (Caêdrum 'n' Bass)
# 27                     Minha Historia                    Samba De Orly
# 28                     Minha Historia     O Que Será (À Flor Da Terra)
# 29                     Minha Historia                   Minha Historia
# 30                     Minha Historia                 Geni E O Zepelim
# 31                     Minha Historia      Construção / Deus Lhe Pague
# 32                                War                     Drowning Man
# 33                                War           Two Hearts Beat As One
# 34                                War                        Surrender
# 35                            Zooropa                          Zooropa
# 36  The Best Of R.E.M.: The IRS Years                Radio Free Aurope
# 37  The Best Of R.E.M.: The IRS Years                   Perfect Circle
#
#                 Nom_Artiste               Genre                        Media  \
# 0                 Green Day  Alternative & Punk              MPEG audio file
# 1                 Green Day  Alternative & Punk              MPEG audio file
# 2                 Green Day  Alternative & Punk              MPEG audio file
# 3             Guns N' Roses                Rock     Protected AAC audio file
# 4             Guns N' Roses                Rock     Protected AAC audio file
# 5             Guns N' Roses                Rock     Protected AAC audio file
# 6             Guns N' Roses                Rock     Protected AAC audio file
# 7             Guns N' Roses               Metal              MPEG audio file
# 8             Guns N' Roses               Metal              MPEG audio file
# 9      Battlestar Galactica    Sci Fi & Fantasy  Protected MPEG-4 video file
# 10                   Heroes               Drama  Protected MPEG-4 video file
# 11                   Heroes               Drama  Protected MPEG-4 video file
# 12                     Lost            TV Shows  Protected MPEG-4 video file
# 13                     Lost            TV Shows  Protected MPEG-4 video file
# 14                     Lost               Drama  Protected MPEG-4 video file
# 15                     Lost               Drama  Protected MPEG-4 video file
# 16                     Lost               Drama  Protected MPEG-4 video file
# 17                     Lost               Drama  Protected MPEG-4 video file
# 18                     Lost            TV Shows  Protected MPEG-4 video file
# 19                       U2                Rock              MPEG audio file
# 20                       U2                Rock              MPEG audio file
# 21                       U2                Rock              MPEG audio file
# 22                       U2                Rock              MPEG audio file
# 23              Soundgarden                Rock              MPEG audio file
# 24              Soundgarden                Rock              MPEG audio file
# 25  Os Paralamas Do Sucesso               Latin              MPEG audio file
# 26           Caetano Veloso               Latin              MPEG audio file
# 27            Chico Buarque               Latin              MPEG audio file
# 28            Chico Buarque               Latin              MPEG audio file
# 29            Chico Buarque               Latin              MPEG audio file
# 30            Chico Buarque               Latin              MPEG audio file
# 31            Chico Buarque               Latin              MPEG audio file
# 32                       U2                Rock              MPEG audio file
# 33                       U2                Rock              MPEG audio file
# 34                       U2                Rock              MPEG audio file
# 35                       U2                Rock              MPEG audio file
# 36                   R.E.M.  Alternative & Punk              MPEG audio file
# 37                   R.E.M.  Alternative & Punk              MPEG audio file
#
#              Date_Achat
# 0   2013-04-05 00:00:00
# 1   2013-04-05 00:00:00
# 2   2013-04-05 00:00:00
# 3   2013-04-05 00:00:00
# 4   2013-04-05 00:00:00
# 5   2013-04-05 00:00:00
# 6   2013-04-05 00:00:00
# 7   2013-04-05 00:00:00
# 8   2013-04-05 00:00:00
# 9   2012-08-05 00:00:00
# 10  2012-08-05 00:00:00
# 11  2012-08-05 00:00:00
# 12  2012-08-05 00:00:00
# 13  2012-08-05 00:00:00
# 14  2012-08-05 00:00:00
# 15  2012-08-05 00:00:00
# 16  2012-08-05 00:00:00
# 17  2012-08-05 00:00:00
# 18  2012-08-05 00:00:00
# 19  2012-08-05 00:00:00
# 20  2012-08-05 00:00:00
# 21  2012-08-05 00:00:00
# 22  2012-08-05 00:00:00
# 23  2012-06-25 00:00:00
# 24  2012-06-25 00:00:00
# 25  2011-01-02 00:00:00
# 26  2010-05-14 00:00:00
# 27  2010-05-14 00:00:00
# 28  2010-05-14 00:00:00
# 29  2010-05-14 00:00:00
# 30  2010-05-14 00:00:00
# 31  2010-05-14 00:00:00
# 32  2010-02-09 00:00:00
# 33  2010-02-09 00:00:00
# 34  2010-02-09 00:00:00
# 35  2010-02-09 00:00:00
# 36  2009-11-07 00:00:00
# 37  2009-11-07 00:00:00

# %% [markdown]
# Q11. Produire la liste de tous les contacts de la base de données (clients & employés) avec leur nom, prénom, type (client ou employé), email, pays et no de téléphone

# %%
query_11_1 = """
    ALTER TABLE customers 
    ADD Type_Personne VARCHAR;

    UPDATE customers 
    SET Type_Personne = 'Client';

    ALTER TABLE employees 
    ADD Type_Personne VARCHAR;

    UPDATE employees 
    SET Type_Personne = 'Employé';
"""

# %%
results = pd.read_sql_query(query_11_1, conn)
results

# %%
query_11 = """
    SELECT Type_Personne,
	   FirstName || ' ' || LastName AS Prénom_Nom, 
	   Email,
	   Phone,
	   Country
    FROM employees
    UNION
    SELECT Type_Personne,
	   FirstName || ' ' || LastName AS Prénom_Nom,
	   Email,
       Phone,
	   Country 
    FROM customers
    ORDER BY Type_Personne, Prénom_Nom;
"""

# %%
results = pd.read_sql_query(query_11, conn)
results
# Out:
#    Type_Personne        Prénom_Nom                     Email  \
# 0         Client    Aaron Mitchell    aaronmitchell@yahoo.ca
# 1         Client   Alexandre Rocha          alero@uol.com.br
# 2         Client     Astrid Gruber    astrid.gruber@apple.at
# 3         Client      Bjørn Hansen     bjorn.hansen@yahoo.no
# 4         Client   Camille Bernard  camille.bernard@yahoo.fr
# ..           ...               ...                       ...
# 62       Employé     Margaret Park  margaret@chinookcorp.com
# 63       Employé  Michael Mitchell   michael@chinookcorp.com
# 64       Employé     Nancy Edwards     nancy@chinookcorp.com
# 65       Employé       Robert King    robert@chinookcorp.com
# 66       Employé     Steve Johnson     steve@chinookcorp.com
#
#                  Phone  Country
# 0    +1 (204) 452-6452   Canada
# 1   +55 (11) 3055-3278   Brazil
# 2       +43 01 5134505  Austria
# 3      +47 22 44 22 22   Norway
# 4   +33 01 49 70 65 65   France
# ..                 ...      ...
# 62   +1 (403) 263-4423   Canada
# 63   +1 (403) 246-9887   Canada
# 64   +1 (403) 262-3443   Canada
# 65   +1 (403) 456-9986   Canada
# 66    1 (780) 836-9987   Canada
#
# [67 rows x 5 columns]

# %% [markdown]
# Q12. Produire la liste de répartition des ventes par pays (basée sur `BillingCountry`)

# %%
query_12 = """
    SELECT Country AS Pays, 
           SUM(II.Quantity) AS Volume_Ventes, 
           ROUND((SUM(II.Quantity)*100/Tot.Tot_Qté)) || ' %' AS Part_Ventes
    FROM customers C,
        (SELECT SUM(II.Quantity) AS Tot_Qté
        FROM invoice_items II) AS Tot
    INNER JOIN invoices I
        ON C.CustomerId = I.CustomerId 
    INNER JOIN invoice_items II
        ON I.InvoiceId = II.InvoiceId 
    GROUP BY Country
    ORDER BY Volume_Ventes DESC;
"""

# %%
results = pd.read_sql_query(query_12, conn)
results.head()
# Out:
#       Pays  Volume_Ventes Part_Ventes
# 0      USA            494      22.0 %
# 1   Canada            304      13.0 %
# 2   France            190       8.0 %
# 3   Brazil            190       8.0 %
# 4  Germany            152       6.0 %

# %%
query_12_b = """
    SELECT Country AS Pays,
	       SUM(I.Total) AS Total_Facturé,
           ROUND((SUM(Total) * 100.0 / Tot.Tot_F)) || '%' AS 'Part_Ventes'
    FROM customers C,
        (SELECT SUM(Total) AS Tot_F
        FROM Invoices I) AS Tot
    INNER JOIN invoices I
        ON C.CustomerId = I.CustomerId 
    GROUP BY Pays 
    ORDER BY Total_Facturé DESC;
"""

# %%
results = pd.read_sql_query(query_12_b, conn)
results.head()
# Out:
#       Pays  Total_Facturé Part_Ventes
# 0      USA         523.06       22.0%
# 1   Canada         303.96       13.0%
# 2   France         195.10        8.0%
# 3   Brazil         190.10        8.0%
# 4  Germany         156.48        7.0%
